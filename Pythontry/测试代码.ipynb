# %%
'''assertEqual(a, b)
核实 a == b
assertNotEqual(a, b)
核实 a != b
assertTrue(x)
核实 x 为 True
assertFalse(x)
核实 x 为 False
assertIn( item , list )
核实 item 在 list 中
assertNotIn( item , list )
核实 item 不在 list 中'''

# %%
import matplotlib.pyplot as plt
input_values=[1,2,3,4,5]
squares = [1, 4, 9, 16, 25]
plt.plot(input_values,squares, linewidth=5)
# 设置图表标题，并给坐标轴加上标签
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
# 设置刻度标记的大小
plt.tick_params(axis='both', labelsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(2,4,s=200)
# 设置图表标题并给坐标轴加上标签
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
# 设置刻度标记的大小
plt.tick_params(axis='both', which='major',labelsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
x_values=[1,2,3,4,5]
y_values=[1,4,9,16,25]
plt.scatter(x_values,y_values,color=(0,0,0.8),edgecolor=None,s=300)
# 设置图表标题并给坐标轴加上标签
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
# 设置刻度标记的大小
plt.tick_params(axis='both', which='major',labelsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
x_values=list(range(1,1001))
y_values=[x**2 for x in x_values]
plt.scatter(x_values,y_values,color=(0.1,0.2,0.3),edgecolor=None,s=40)
# 设置图表标题并给坐标轴加上标签
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
# 设置刻度标记的大小
plt.tick_params(axis='both', which='major',labelsize=14)
plt.axis([0, 1100, 0, 1100000])
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = list(range(1001))
y_values = [x**2 for x in x_values]
plt.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Greys,#从官方找示例做，都弄好了
edgecolor=None, s=40)
# 设置图表标题并给坐标轴加上标签
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
# 设置刻度标记的大小
plt.tick_params(axis='both', which='major',labelsize=14)
plt.axis([0, 1100, 0, 1100000])
plt.savefig('squares_plot.png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
x_values=list(range(1,6))
y_values=[x**3 for x in x_values]
plt.scatter(x_values,y_values,c=y_values,cmap=plt.cm.Greys)#指定好了必须用c和它的cmap
plt.show()

# %%
import matplotlib.pyplot as plt
x_values=list(range(1,5001))
y_values=[x**3 for x in x_values]
plt.scatter(x_values,y_values,s=10,edgecolor=None,c=y_values,cmap=plt.cm.Oranges)#一个详细一个缩写，是颜色映射
plt.title('Cube Numbers',fontsize=24)
plt.xlabel('value',fontsize=14)
plt.ylabel('cube of value',fontsize=14)
plt.savefig('cube_plot.png',bbox_inches='tight')

# %%
import random
import matplotlib.pyplot as plt

def random_walk(steps):
    x = 0
    y = 0
    x_vals = [x]
    y_vals = [y]
    
    for _ in range(steps):
        direction = random.choice(['up', 'down', 'left', 'right'])
        
        if direction == 'up':
            y += 1
        elif direction == 'down':
            y -= 1
        elif direction == 'left':
            x -= 1
        elif direction == 'right':
            x += 1
        
        x_vals.append(x)
        y_vals.append(y)
    
    return x_vals, y_vals

steps = 1000
x, y = random_walk(steps)

plt.plot(x, y)
plt.title('Random Walk')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

def random_walk(steps):
    x = 0
    y = 0
    x_vals = [x]
    y_vals = [y]
    
    for _ in range(steps):
        direction = random.choice(['up', 'down', 'left', 'right'])
        
        if direction == 'up':
            y += 1
        elif direction == 'down':
            y -= 1
        elif direction == 'left':
            x -= 1
        elif direction == 'right':
            x += 1
        
        x_vals.append(x)
        y_vals.append(y)
    
    return x_vals, y_vals

steps = 5000
x, y = random_walk(steps)

plt.scatter(x, y, c=range(steps+1), cmap='viridis', edgecolors='none')
plt.title('Random Walk')
plt.axis('off')
plt.show()

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

def random_walk(steps):
    x = 0
    y = 0
    x_vals = [x]
    y_vals = [y]
    
    for _ in range(steps):
        direction = random.choice(['up', 'down', 'left', 'right'])
        
        if direction == 'up':
            y += 1
        elif direction == 'down':
            y -= 1
        elif direction == 'left':
            x -= 1
        elif direction == 'right':
            x += 1
        
        x_vals.append(x)
        y_vals.append(y)
    
    return x_vals, y_vals

steps = 1000
x, y = random_walk(steps)

plt.plot(x, y)
plt.title('Random Walk')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

def random_walk(steps):
    x = 0
    y = 0
    x_vals = [x]
    y_vals = [y]
    
    for _ in range(steps):
        direction = random.choice(['up', 'down', 'left', 'right'])
        
        if direction == 'up':
            y += 1
        elif direction == 'down':
            y -= 1
        elif direction == 'left':
            x -= 1
        elif direction == 'right':
            x += 1
        
        x_vals.append(x)
        y_vals.append(y)
    
    return x_vals, y_vals

steps = 1000
x, y = random_walk(steps)

plt.plot(x, y)
plt.title('Random Walk')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
import turtle
CAP_X=[
    [-171.57,-182.56,-189.84,-195.21,-196.99,-207.02,-217.8,
    -220.31,-228.45,-236.85,-242.03,-251.99,-254.3,-250.85,-243.92,
    -224.08,-205.59,-201.28,-187.77,-170.37,-166.92,-166.84,-169.49,
    -177.49,-189.16,-191.33,-190.16,-182,-171.28,-156.62,-139.64,-131.71,
    -121.07,-112.24,-102.03,-93.78,-87.41,-82.67,-83.13,-84.01,-84.79,-85.5,
    -86.21,-86.76,-87.12,-86.54,-85.89,-84.72,-83.65,-79.68,-71.82,-57.63,
    -45.09,-31.63,-25.5,-18.26,-16.05,-13.39,-11.4,-10.62,-10.6,-12.37,-16,
    -16.72,-17.61,-17.77,-17.5,-9.57,-1.5,13.4,32.31,51.44,75.12,102.03,
    119.18,121.48,121.69,120.21,107.47,106.29,105.79,106.03,108.8,
    111.15,118.35,127.63,137.27,138.62,139.85,143.21,146.43,149.66,
    150.7,157.29,158.9,159.78,160.91,167.56,181.73,194.83,205.87,213.62,
    216.71,219.26,221.84,217.06,209.55,203.29,203.39,206.25,208.37,210.4,
    213.88,215.52,224.56,233.29,243.76,248.56,249.92,250.8,248.88,245.1,240.23,
    232.26,222.22,218.51,214.71,212.22,201.41,169.58],
    [-176.83,-178.86,-178.52,-174.8,-158.53,-138.32,-113.71,-102.44,-97.4,-80.78,-54.6,-23.43,-15.78],
    [77.5,89.07,113.14,134.49,146.62,159.65,170.54,170.79],
    [-149.84,-181.52,-183.7,-183.92,-183.82,-195.41,-225.69,-261,-279.89,-282.61,
    -285.18,-288.43,-288.36,-280.35,-260.09,-243.88,-217.4,-193.48,-185.53,-179.37,-188.29,
    -195.9,-203.17,-223.72,-235.19,-241.92,-244.29,-246,-245.22,-245.27,-244.55,-233.55,
    -209.12,-207.36],
    [-196.23,-200.55,-205.12,-206.74,-207.31,-206.74,-203.26,-195.9,-189.01,-177.32,
    -163.33,-151.99,-143.48,-133.26,-120.6,-113.98,-110.85,-110.4],
    [189.85,193.07,207.69,234.07,254.47,256.34,259.34,260.93,260.32,249.47,233.98,
    216.5,198.91,189.69,179.3,172.71,175.66,178.46,181.05,185.73,201.75,216.14,225.41,222.66,
    219.74,218.88,215.71,199.55,187.73,188.52,188.82,186.93,183.26,178.14,169.9,160.36,153.59,
    145.36,135.12,123.84,114.45,109.45,106.4,100.91,97.31,96.28],
    [130.89,123.81,115.89,106.45,100.07,86.14,70.25,61.38,42.6,30.6,24.54,16.18,10.62,6.28,
    [-6.44,-5.25,-6.7,-6,-7.26,-6.71,-7.86,-7.64,-8.37,-8.13,-8.8,-8.69,-9.22,-9.35,-9.59,-9.8,-10.13,-10.21,-10.36,-10.47,
    -10.53,-10.62,-11.03,-11.96,-12.57,-13.46,-14.3,-15.45,-15.58,-16.1,-16.03,-16.6,-16.35,-16.97,-16.82,-17.33,
    -17.1,-17.57,-17.3,-17.78,-17.5,-18.02,-17.88,-18.32,-17.75],
    [-3.25,-4.66,-8.72,-12.06,-14.89,-18.23,-21.56,-22.9,-24.27,-25.2,-25.88,-26.2,-26.44,-27.07,-27.95,-28.88,-29.85,
    -30.15,-30.4,-30.32,-29.99,-29.19,-28.66,-26.81,-23.85,-20.21,-16.86,-13.99,-12.44]
]
righteye_x=[
    [50,61.25,72.99,82.35,92.36,104.33],
    [107.58,95.98,81.81,67.03,53.9,48.76],
    [105.04,94.8,83.26,67.9,51.71,46.59],
    [48.36,63.78,79.3,89.82,92.36,97.02,102.26],
    [92.36,94.02,95.78,98.32,101.04,104.1,104.1],
    [92.31,93.97,95.73,98.27,100.99,104.05,104.05],
    [56.27,56.36,56.56,56.75,56.94,57.43,58.77,63.06,70.02,79.84,86.94,87.76,88.44,88.91,88.85,88.5,88.57,88.74,88.96],
    [67.96,79.86,68.7,79.04,69.39,78.3,69.79,76.54,70.24,75.29,70.47,73.86,70.56,72.77,70.63,72.12,70.62,71.77,70.44,
    70.49,70.16,70.22,69.89,69.95,69.57,69.63,69.12,69.1,68.55,68.36,67.63,67.48,66.7,66.24,65.05,64.01,62.95,
    61.52,60.56,59.33,58.25,56.62]
]
righteye_y=[
    [0.73,0.73,0.46,0.38,0.15,-0.57],
    [-1.93,-1.03,-0.87,-0.63,-0.47,-0.51],
    [-2.67,-2.21,-2.12,-2.02,-2.02,-2.12],
    [-4.05,-4.13,-4.13,-3.96,-4.31,-4.6,-4.74],
    [-4.31,-6.06,-7.29,-8.34,-9.21,-10.09,-10.09],
    [-4.6,-6.35,-7.57,-8.63,-9.5,-10.38,-10.38],
    [-7.81,-12.93,-17.77,-23,-24.45,-25.38,-25.76,-25.85,-26,-25.95,-25.71,-25.53,-25.2,-24.18,-21.1,-12.08,-7.67,-5.5,-4.05],
    [-5.32,-5.52,-5.81,-6.08,-6.29,-6.54,-7.04,-7.37,-7.45,-7.86,-7.84,-8.25,-8.18,-8.58,-8.45,-8.77,-8.75,-8.93,-9.19,-9.33,-9.37,
    -9.6,-9.59,-9.88,-9.84,-10.14,-10.19,-10.54,-10.52,-10.97,-11.03,-11.53,-11.57,-12.22,-12.82,-13.01,-13.95,-13.82,-14.53,
    -14.44,-15.01,-14.49]
]

def move(x:list,y:list)->None: 
    for i in range(len(x)):
        turtle.penup()
        turtle.goto(x[i][0],y[i][0])
        turtle.pendown()
        for j in range(len(x[i])):
            turtle.goto(x[i][j],y[i][j])

turtle.setup(600,600)
turtle.title("帕秋莉！GO！")
turtle.hideturtle()
move(CAP_X,CAP_Y)
move(face_x,face_y)
move(hair_x,hair_y)
move(body_x,body_y)
move(DETAIL_X,DETAIL_Y)
move(face_detail_x,face_detail_y)
move(lefteye_x,lefteye_y)
move(righteye_x,righteye_y)
turtle.done()
